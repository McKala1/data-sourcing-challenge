# %% [markdown]
# ### Import Required Libraries and Set Up Environment Variables

# %%
# Dependencies
import requests
import time
from dotenv import load_dotenv
import os
import pandas as pd
import json

# %%
# Set environment variables from the .env in the local environment
load_dotenv('../M6_Starter_Code/example.env')


#nyt_api_key = os.getenv(r"C:\Users\mckal\OneDrive\Desktop\OSU-VIRT-AI-PT-10-2023-U-LOLC\hmwk 6\M6_Starter_Code\M6_Starter_Code\example.env")
#tmdb_api_key = os.getenv("../M6_Starter_Code/example.env")
# Out:
# True

# %%
nyt_api_key = os.getenv("NYT_API_KEY")
tmdb_api_key = os.getenv("TMDB_API_KEY")

# %% [markdown]
# ### Access the New York Times API

# %%
# Set the base URL
url = "https://api.nytimes.com/svc/search/v2/articlesearch.json?"

# Filter for movie reviews with "love" in the headline
# section_name should be "Movies"
# type_of_material should be "Review"
filter_query = 'section_name:"Movies" AND type_of_material:"Review" AND headline:"love"'

# Use a sort filter, sort by newest
sort = "newest"

# Select the following fields to return:
# headline, web_url, snippet, source, keywords, pub_date, byline, word_count
field_list = "headline,web_url,snippet,source,keywords,pub_date,byline,word_count"

# Search for reviews published between a begin and end date
begin_date = "20130101"
end_date = "20230531"

# Build URL

query_url = (f"{url}api-key={nyt_api_key}&begin_date={begin_date}&end_date={end_date}" + f'&fq={filter_query}&sort={sort}&fl={field_list}')

# %%
# Create an empty list to store the reviews
reviews_list = []

# loop through pages 0-19
for page in range (0, 20):
    # create query with a page number
    # API results show 10 articles at a time
    page_query_url = f"{query_url}&page={page}"
    #print(page_query_url)
    
    #page_query_url.head(10)
    #GET /api/articles

    # Make a "GET" request and retrieve the JSON
    # response = requests.get(query_url).json()
    # print(response)    

    reviews = requests.get(query_url).json()
    
    # Add a twelve second interval between queries to stay within API query limits
    time.sleep(12)
    
    # Try and save the reviews to the reviews_list
    try:
        # loop through the reviews["response"]["docs"] and append each review to the list
        for review in reviews["response"]["docs"]:
            reviews_list.append(review)
        # Print the page that was just retrieved
        print(f"Page {page} retrieved")


        # Print the page number that had no results then break from the loop
    except:
        print(f"Page {page} does not have any results")
        break
# Out:
# Page 0 retrieved
# Page 1 retrieved
# Page 2 retrieved
# Page 3 retrieved
# Page 4 retrieved
# Page 5 retrieved
# Page 6 retrieved
# Page 7 retrieved
# Page 8 retrieved
# Page 9 retrieved
# Page 10 retrieved
# Page 11 retrieved
# Page 12 retrieved
# Page 13 retrieved
# Page 14 retrieved
# Page 15 retrieved
# Page 16 retrieved
# Page 17 retrieved
# Page 18 retrieved
# Page 19 retrieved

# %%
# Preview the first 5 results in JSON format
# Use json.dumps with argument indent=4 to format data

first_5_results = (json.dumps(reviews_list[:5], indent=4))
print(first_5_results)
# Out:
# [
#     {
#         "web_url": "https://www.nytimes.com/2023/05/25/movies/the-attachment-diaries-review.html",
#         "snippet": "A gynecologist and her patient form a horrifyingly twisted connection in this batty, bloody Argentine melodrama.",
#         "source": "The New York Times",
#         "headline": {
#             "main": "\u2018The Attachment Diaries\u2019 Review: Love, Sick",
#             "kicker": null,
#             "content_kicker": null,
#             "print_headline": "The Attachment Diaries",
#             "name": null,
#             "seo": null,
#             "sub": null
#         },
#         "keywords": [
#             {
#                 "name": "subject",
#                 "value": "Movies",
#                 "rank": 1,
#                 "major": "N"
#             },
#             {
#                 "name": "creative_works",
#                 "value": "The Attachment Diaries (Movie)",
#                 "rank": 2,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Diment, Valentin Javier",
#                 "rank": 3,
#                 "major": "N"
#             }
#         ],
#         "pub_date": "2023-05-25T11:00:03+0000",
#         "byline": {
#             "original": "By Jeannette Catsoulis",
#             "person": [
#                 {
#                     "firstname": "Jeannette",
#                     "middlename": null,
#                     "lastname": "Catsoulis",
#                     "qualifier": null,
#                     "title": null,
#                     "role": "reported",
#                     "organization": "",
#                     "rank": 1
#                 }
#             ],
#             "organization": null
#         },
#         "word_count": 295
#     },
#     {
#         "web_url": "https://www.nytimes.com/2023/05/04/movies/whats-love-got-to-do-with-it-review.html",
#         "snippet": "Two childhood friends navigate cultural differences in this pleasantly uncontentious romantic comedy.",
#         "source": "The New York Times",
#         "headline": {
#             "main": "Review: \u2018What\u2019s Love Got to Do With It?\u2019 Probably a Lot",
#             "kicker": null,
#             "content_kicker": null,
#             "print_headline": "What\u2019s Love Got to Do With It?",
#             "name": null,
#             "seo": null,
#             "sub": null
#         },
#         "keywords": [
#             {
#                 "name": "subject",
#                 "value": "Movies",
#                 "rank": 1,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Kapur, Shekhar",
#                 "rank": 2,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "James, Lily",
#                 "rank": 3,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Azmi, Shabana",
#                 "rank": 4,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Thompson, Emma",
#                 "rank": 5,
#                 "major": "N"
#             }
#         ],
#         "pub_date": "2023-05-04T17:16:45+0000",
#         "byline": {
#             "original": "By Jeannette Catsoulis",
#             "person": [
#                 {
#                     "firstname": "Jeannette",
#                     "middlename": null,
#                     "lastname": "Catsoulis",
#                     "qualifier": null,
#                     "title": null,
#                     "role": "reported",
#                     "organization": "",
#                     "rank": 1
#                 }
#             ],
#             "organization": null
#         },
#         "word_count": 287
#     },
#     {
#         "web_url": "https://www.nytimes.com/2023/05/04/movies/you-can-live-forever-review.html",
#         "snippet": "Religion comes between two girls falling in love in the 1990s in this sweet coming-of-age film bathed in grunge hues.",
#         "source": "The New York Times",
#         "headline": {
#             "main": "\u2018You Can Live Forever\u2019 Review: Do You Love Me Now?",
#             "kicker": null,
#             "content_kicker": null,
#             "print_headline": "You Can Live Forever",
#             "name": null,
#             "seo": null,
#             "sub": null
#         },
#         "keywords": [
#             {
#                 "name": "subject",
#                 "value": "Movies",
#                 "rank": 1,
#                 "major": "N"
#             },
#             {
#                 "name": "creative_works",
#                 "value": "You Can Live Forever (Movie)",
#                 "rank": 2,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Slutsky, Mark",
#                 "rank": 3,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Watts, Sarah (Film Director)",
#                 "rank": 4,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "O'Driscoll, Anwen",
#                 "rank": 5,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Laporte, June (Actor)",
#                 "rank": 6,
#                 "major": "N"
#             }
#         ],
#         "pub_date": "2023-05-04T11:00:08+0000",
#         "byline": {
#             "original": "By Elisabeth Vincentelli",
#             "person": [
#                 {
#                     "firstname": "Elisabeth",
#                     "middlename": null,
#                     "lastname": "Vincentelli",
#                     "qualifier": null,
#                     "title": null,
#                     "role": "reported",
#                     "organization": "",
#                     "rank": 1
#                 }
#             ],
#             "organization": null
#         },
#         "word_count": 294
#     },
#     {
#         "web_url": "https://www.nytimes.com/2023/04/21/movies/a-tourists-guide-to-love-review.html",
#         "snippet": "Rachael Leigh Cook stars in this bland rom-com as a travel executive exploring Vietnam and getting over a breakup.",
#         "source": "The New York Times",
#         "headline": {
#             "main": "\u2018A Tourist\u2019s Guide to Love\u2019 Review: A Wearyingly Familiar Trip",
#             "kicker": null,
#             "content_kicker": null,
#             "print_headline": "A Tourist\u2019s  Guide to Love",
#             "name": null,
#             "seo": null,
#             "sub": null
#         },
#         "keywords": [
#             {
#                 "name": "subject",
#                 "value": "Movies",
#                 "rank": 1,
#                 "major": "N"
#             },
#             {
#                 "name": "creative_works",
#                 "value": "A Tourist's Guide to Love (Movie)",
#                 "rank": 2,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Tsuchida, Steven",
#                 "rank": 3,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Cook, Rachael Leigh",
#                 "rank": 4,
#                 "major": "N"
#             }
#         ],
#         "pub_date": "2023-04-21T07:03:25+0000",
#         "byline": {
#             "original": "By Elisabeth Vincentelli",
#             "person": [
#                 {
#                     "firstname": "Elisabeth",
#                     "middlename": null,
#                     "lastname": "Vincentelli",
#                     "qualifier": null,
#                     "title": null,
#                     "role": "reported",
#                     "organization": "",
#                     "rank": 1
#                 }
#             ],
#             "organization": null
#         },
#         "word_count": 276
#     },
#     {
#         "web_url": "https://www.nytimes.com/2023/04/20/movies/other-peoples-children-review.html",
#         "snippet": "A radiant Virginie Efira stars as a Parisian teacher who blissfully falls for a man and his 4-year-old daughter, complicating everyone\u2019s lives.",
#         "source": "The New York Times",
#         "headline": {
#             "main": "\u2018Other People\u2019s Children\u2019 Review: True Romance",
#             "kicker": "Critic\u2019s pick",
#             "content_kicker": null,
#             "print_headline": "Intoxicating Love With a Sobering Turn",
#             "name": null,
#             "seo": null,
#             "sub": null
#         },
#         "keywords": [
#             {
#                 "name": "subject",
#                 "value": "Movies",
#                 "rank": 1,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Zlotowski, Rebecca",
#                 "rank": 2,
#                 "major": "N"
#             },
#             {
#                 "name": "creative_works",
#                 "value": "Other People's Children (Movie)",
#                 "rank": 3,
#                 "major": "N"
#             }
#         ],
#         "pub_date": "2023-04-20T15:35:13+0000",
#         "byline": {
#             "original": "By Manohla Dargis",
#             "person": [
#                 {
#                     "firstname": "Manohla",
#                     "middlename": null,
#                     "lastname": "Dargis",
#                     "qualifier": null,
#                     "title": null,
#                     "role": "reported",
#                     "organization": "",
#                     "rank": 1
#                 }
#             ],
#             "organization": null
#         },
#         "word_count": 801
#     }
# ]

# %%
# Convert reviews_list to a Pandas DataFrame using json_normalize()
reviews_df = pd.json_normalize(reviews_list)
reviews_df.head()
# Out:
#                                              web_url  \
# 0  https://www.nytimes.com/2023/05/25/movies/the-...
# 1  https://www.nytimes.com/2023/05/04/movies/what...
# 2  https://www.nytimes.com/2023/05/04/movies/you-...
# 3  https://www.nytimes.com/2023/04/21/movies/a-to...
# 4  https://www.nytimes.com/2023/04/20/movies/othe...
#
#                                              snippet              source  \
# 0  A gynecologist and her patient form a horrifyi...  The New York Times
# 1  Two childhood friends navigate cultural differ...  The New York Times
# 2  Religion comes between two girls falling in lo...  The New York Times
# 3  Rachael Leigh Cook stars in this bland rom-com...  The New York Times
# 4  A radiant Virginie Efira stars as a Parisian t...  The New York Times
#
#                                             keywords  \
# 0  [{'name': 'subject', 'value': 'Movies', 'rank'...
# 1  [{'name': 'subject', 'value': 'Movies', 'rank'...
# 2  [{'name': 'subject', 'value': 'Movies', 'rank'...
# 3  [{'name': 'subject', 'value': 'Movies', 'rank'...
# 4  [{'name': 'subject', 'value': 'Movies', 'rank'...
#
#                    pub_date  word_count  \
# 0  2023-05-25T11:00:03+0000         295
# 1  2023-05-04T17:16:45+0000         287
# 2  2023-05-04T11:00:08+0000         294
# 3  2023-04-21T07:03:25+0000         276
# 4  2023-04-20T15:35:13+0000         801
#
#                                        headline.main headline.kicker  \
# 0        ‘The Attachment Diaries’ Review: Love, Sick            None
# 1  Review: ‘What’s Love Got to Do With It?’ Proba...            None
# 2  ‘You Can Live Forever’ Review: Do You Love Me ...            None
# 3  ‘A Tourist’s Guide to Love’ Review: A Wearying...            None
# 4     ‘Other People’s Children’ Review: True Romance   Critic’s pick
#
#   headline.content_kicker                 headline.print_headline  \
# 0                    None                  The Attachment Diaries
# 1                    None          What’s Love Got to Do With It?
# 2                    None                    You Can Live Forever
# 3                    None              A Tourist’s  Guide to Love
# 4                    None  Intoxicating Love With a Sobering Turn
#
#   headline.name headline.seo headline.sub           byline.original  \
# 0          None         None         None    By Jeannette Catsoulis
# 1          None         None         None    By Jeannette Catsoulis
# 2          None         None         None  By Elisabeth Vincentelli
# 3          None         None         None  By Elisabeth Vincentelli
# 4          None         None         None         By Manohla Dargis
#
#                                        byline.person byline.organization
# 0  [{'firstname': 'Jeannette', 'middlename': None...                None
# 1  [{'firstname': 'Jeannette', 'middlename': None...                None
# 2  [{'firstname': 'Elisabeth', 'middlename': None...                None
# 3  [{'firstname': 'Elisabeth', 'middlename': None...                None
# 4  [{'firstname': 'Manohla', 'middlename': None, ...                None

# %%
# Extract the title from the "headline.main" column and
# save it to a new column "title"
# Title is between unicode characters \u2018 and \u2019. 
# End string should include " Review" to avoid cutting title early
reviews_df['title'] = reviews_df['headline.main'].str.extract(r"\u2018(.*)\u2019\s*Review")
reviews_df.head(3)



#EXAMPLE lambda st: st[st.find("\u2018")+1:st.find("\u2019 Review")]
# Out:
#                                              web_url  \
# 0  https://www.nytimes.com/2023/05/25/movies/the-...
# 1  https://www.nytimes.com/2023/05/04/movies/what...
# 2  https://www.nytimes.com/2023/05/04/movies/you-...
#
#                                              snippet              source  \
# 0  A gynecologist and her patient form a horrifyi...  The New York Times
# 1  Two childhood friends navigate cultural differ...  The New York Times
# 2  Religion comes between two girls falling in lo...  The New York Times
#
#                                             keywords  \
# 0  [{'name': 'subject', 'value': 'Movies', 'rank'...
# 1  [{'name': 'subject', 'value': 'Movies', 'rank'...
# 2  [{'name': 'subject', 'value': 'Movies', 'rank'...
#
#                    pub_date  word_count  \
# 0  2023-05-25T11:00:03+0000         295
# 1  2023-05-04T17:16:45+0000         287
# 2  2023-05-04T11:00:08+0000         294
#
#                                        headline.main headline.kicker  \
# 0        ‘The Attachment Diaries’ Review: Love, Sick            None
# 1  Review: ‘What’s Love Got to Do With It?’ Proba...            None
# 2  ‘You Can Live Forever’ Review: Do You Love Me ...            None
#
#   headline.content_kicker         headline.print_headline headline.name  \
# 0                    None          The Attachment Diaries          None
# 1                    None  What’s Love Got to Do With It?          None
# 2                    None            You Can Live Forever          None
#
#   headline.seo headline.sub           byline.original  \
# 0         None         None    By Jeannette Catsoulis
# 1         None         None    By Jeannette Catsoulis
# 2         None         None  By Elisabeth Vincentelli
#
#                                        byline.person byline.organization  \
# 0  [{'firstname': 'Jeannette', 'middlename': None...                None
# 1  [{'firstname': 'Jeannette', 'middlename': None...                None
# 2  [{'firstname': 'Elisabeth', 'middlename': None...                None
#
#                     title
# 0  The Attachment Diaries
# 1                     NaN
# 2    You Can Live Forever

# %%
# Extract 'name' and 'value' from items in "keywords" column
def extract_keywords(keyword_list):
    extracted_keywords = ""
    for item in keyword_list:
        # Extract 'name' and 'value'
        keyword = f"{item['name']}: {item['value']};" 
        # Append the keyword item to the extracted_keywords list
        extracted_keywords += keyword
    return extracted_keywords

# Fix the "keywords" column by converting cells from a list to a string
reviews_df["keywords"] = reviews_df["keywords"].apply(extract_keywords)
reviews_df
# Out:
#                                                web_url  \
# 0    https://www.nytimes.com/2023/05/25/movies/the-...
# 1    https://www.nytimes.com/2023/05/04/movies/what...
# 2    https://www.nytimes.com/2023/05/04/movies/you-...
# 3    https://www.nytimes.com/2023/04/21/movies/a-to...
# 4    https://www.nytimes.com/2023/04/20/movies/othe...
# ..                                                 ...
# 195  https://www.nytimes.com/2023/04/13/movies/one-...
# 196  https://www.nytimes.com/2023/04/13/movies/the-...
# 197  https://www.nytimes.com/2023/03/30/movies/a-th...
# 198  https://www.nytimes.com/2023/02/09/movies/your...
# 199  https://www.nytimes.com/2023/02/02/movies/love...
#
#                                                snippet              source  \
# 0    A gynecologist and her patient form a horrifyi...  The New York Times
# 1    Two childhood friends navigate cultural differ...  The New York Times
# 2    Religion comes between two girls falling in lo...  The New York Times
# 3    Rachael Leigh Cook stars in this bland rom-com...  The New York Times
# 4    A radiant Virginie Efira stars as a Parisian t...  The New York Times
# ..                                                 ...                 ...
# 195  A film adaptation of Taylor Jenkins Reid’s nov...  The New York Times
# 196  There’s not much Lennon music heard in this do...  The New York Times
# 197  A mesmerizing Teyana Taylor stars in A.V. Rock...  The New York Times
# 198  This humdrum Netflix romantic comedy features ...  The New York Times
# 199  To combat the overdose crisis, a group that in...  The New York Times
#
#                                               keywords  \
# 0    subject: Movies;creative_works: The Attachment...
# 1    subject: Movies;persons: Kapur, Shekhar;person...
# 2    subject: Movies;creative_works: You Can Live F...
# 3    subject: Movies;creative_works: A Tourist's Gu...
# 4    subject: Movies;persons: Zlotowski, Rebecca;cr...
# ..                                                 ...
# 195  subject: Movies;persons: Bracey, Luke (1989- )...
# 196  subject: Documentary Films and Programs;creati...
# 197  subject: Movies;creative_works: A Thousand and...
# 198  subject: Movies;creative_works: Your Place or ...
# 199  subject: Documentary Films and Programs;subjec...
#
#                      pub_date  word_count  \
# 0    2023-05-25T11:00:03+0000         295
# 1    2023-05-04T17:16:45+0000         287
# 2    2023-05-04T11:00:08+0000         294
# 3    2023-04-21T07:03:25+0000         276
# 4    2023-04-20T15:35:13+0000         801
# ..                        ...         ...
# 195  2023-04-13T11:00:06+0000         320
# 196  2023-04-13T11:00:03+0000         327
# 197  2023-03-30T18:53:42+0000         971
# 198  2023-02-10T00:00:05+0000         569
# 199  2023-02-02T12:00:11+0000         306
#
#                                          headline.main headline.kicker  \
# 0          ‘The Attachment Diaries’ Review: Love, Sick            None
# 1    Review: ‘What’s Love Got to Do With It?’ Proba...            None
# 2    ‘You Can Live Forever’ Review: Do You Love Me ...            None
# 3    ‘A Tourist’s Guide to Love’ Review: A Wearying...            None
# 4       ‘Other People’s Children’ Review: True Romance   Critic’s pick
# ..                                                 ...             ...
# 195     ‘One True Loves’ Review: A Romance Lost at Sea            None
# 196  ‘The Lost Weekend: A Love Story’ Review: When ...            None
# 197  ‘A Thousand and One’ Review: A New York Love S...   Critic’s Pick
# 198           ‘Your Place or Mine’ Review: Try Neither            None
# 199  ‘Love in the Time of Fentanyl’ Review: Heartbr...            None
#
#     headline.content_kicker                  headline.print_headline  \
# 0                      None                   The Attachment Diaries
# 1                      None           What’s Love Got to Do With It?
# 2                      None                     You Can Live Forever
# 3                      None               A Tourist’s  Guide to Love
# 4                      None   Intoxicating Love With a Sobering Turn
# ..                      ...                                      ...
# 195                    None                           One True Loves
# 196                    None          The Lost Weekend:  A Love Story
# 197                    None  An Unbending Will Meets a Shifting City
# 198                    None         They Have a Humdrum Kind of Love
# 199                    None             Love in the Time Of Fentanyl
#
#     headline.name headline.seo headline.sub           byline.original  \
# 0            None         None         None    By Jeannette Catsoulis
# 1            None         None         None    By Jeannette Catsoulis
# 2            None         None         None  By Elisabeth Vincentelli
# 3            None         None         None  By Elisabeth Vincentelli
# 4            None         None         None         By Manohla Dargis
# ..            ...          ...          ...                       ...
# 195          None         None         None             By Brandon Yu
# 196          None         None         None            By Glenn Kenny
# 197          None         None         None         By Manohla Dargis
# 198          None         None         None          By Amy Nicholson
# 199          None         None         None     By Concepción de León
#
#                                          byline.person byline.organization  \
# 0    [{'firstname': 'Jeannette', 'middlename': None...                None
# 1    [{'firstname': 'Jeannette', 'middlename': None...                None
# 2    [{'firstname': 'Elisabeth', 'middlename': None...                None
# 3    [{'firstname': 'Elisabeth', 'middlename': None...                None
# 4    [{'firstname': 'Manohla', 'middlename': None, ...                None
# ..                                                 ...                 ...
# 195  [{'firstname': 'Brandon', 'middlename': None, ...                None
# 196  [{'firstname': 'Glenn', 'middlename': None, 'l...                None
# 197  [{'firstname': 'Manohla', 'middlename': None, ...                None
# 198  [{'firstname': 'Amy', 'middlename': None, 'las...                None
# 199  [{'firstname': 'Concepción', 'middlename': Non...                None
#
#                               title
# 0            The Attachment Diaries
# 1                               NaN
# 2              You Can Live Forever
# 3         A Tourist’s Guide to Love
# 4           Other People’s Children
# ..                              ...
# 195                  One True Loves
# 196  The Lost Weekend: A Love Story
# 197              A Thousand and One
# 198              Your Place or Mine
# 199    Love in the Time of Fentanyl
#
# [200 rows x 17 columns]

# %%
# Create a list from the "title" column using to_list()
# These titles will be used in the query for The Movie Database
list_of_titles = (reviews_df["title"].dropna()).to_list()
list_of_titles
# Out:
# ['The Attachment Diaries',
#  'You Can Live Forever',
#  'A Tourist’s Guide to Love',
#  'Other People’s Children',
#  'One True Loves',
#  'The Lost Weekend: A Love Story',
#  'A Thousand and One',
#  'Your Place or Mine',
#  'Love in the Time of Fentanyl',
#  'The Attachment Diaries',
#  'You Can Live Forever',
#  'A Tourist’s Guide to Love',
#  'Other People’s Children',
#  'One True Loves',
#  'The Lost Weekend: A Love Story',
#  'A Thousand and One',
#  'Your Place or Mine',
#  'Love in the Time of Fentanyl',
#  'The Attachment Diaries',
#  'You Can Live Forever',
#  'A Tourist’s Guide to Love',
#  'Other People’s Children',
#  'One True Loves',
#  'The Lost Weekend: A Love Story',
#  'A Thousand and One',
#  'Your Place or Mine',
#  'Love in the Time of Fentanyl',
#  'The Attachment Diaries',
#  'You Can Live Forever',
#  'A Tourist’s Guide to Love',
#  'Other People’s Children',
#  'One True Loves',
#  'The Lost Weekend: A Love Story',
#  'A Thousand and One',
#  'Your Place or Mine',
#  'Love in the Time of Fentanyl',
#  'The Attachment Diaries',
#  'You Can Live Forever',
#  'A Tourist’s Guide to Love',
#  'Other People’s Children',
#  'One True Loves',
#  'The Lost Weekend: A Love Story',
#  'A Thousand and One',
#  'Your Place or Mine',
#  'Love in the Time of Fentanyl',
#  'The Attachment Diaries',
#  'You Can Live Forever',
#  'A Tourist’s Guide to Love',
#  'Other People’s Children',
#  'One True Loves',
#  'The Lost Weekend: A Love Story',
#  'A Thousand and One',
#  'Your Place or Mine',
#  'Love in the Time of Fentanyl',
#  'The Attachment Diaries',
#  'You Can Live Forever',
#  'A Tourist’s Guide to Love',
#  'Other People’s Children',
#  'One True Loves',
#  'The Lost Weekend: A Love Story',
#  'A Thousand and One',
#  'Your Place or Mine',
#  'Love in the Time of Fentanyl',
#  'The Attachment Diaries',
#  'You Can Live Forever',
#  'A Tourist’s Guide to Love',
#  'Other People’s Children',
#  'One True Loves',
#  'The Lost Weekend: A Love Story',
#  'A Thousand and One',
#  'Your Place or Mine',
#  'Love in the Time of Fentanyl',
#  'The Attachment Diaries',
#  'You Can Live Forever',
#  'A Tourist’s Guide to Love',
#  'Other People’s Children',
#  'One True Loves',
#  'The Lost Weekend: A Love Story',
#  'A Thousand and One',
#  'Your Place or Mine',
#  'Love in the Time of Fentanyl',
#  'The Attachment Diaries',
#  'You Can Live Forever',
#  'A Tourist’s Guide to Love',
#  'Other People’s Children',
#  'One True Loves',
#  'The Lost Weekend: A Love Story',
#  'A Thousand and One',
#  'Your Place or Mine',
#  'Love in the Time of Fentanyl',
#  'The Attachment Diaries',
#  'You Can Live Forever',
#  'A Tourist’s Guide to Love',
#  'Other People’s Children',
#  'One True Loves',
#  'The Lost Weekend: A Love Story',
#  'A Thousand and One',
#  'Your Place or Mine',
#  'Love in the Time of Fentanyl',
#  'The Attachment Diaries',
#  'You Can Live Forever',
#  'A Tourist’s Guide to Love',
#  'Other People’s Children',
#  'One True Loves',
#  'The Lost Weekend: A Love Story',
#  'A Thousand and One',
#  'Your Place or Mine',
#  'Love in the Time of Fentanyl',
#  'The Attachment Diaries',
#  'You Can Live Forever',
#  'A Tourist’s Guide to Love',
#  'Other People’s Children',
#  'One True Loves',
#  'The Lost Weekend: A Love Story',
#  'A Thousand and One',
#  'Your Place or Mine',
#  'Love in the Time of Fentanyl',
#  'The Attachment Diaries',
#  'You Can Live Forever',
#  'A Tourist’s Guide to Love',
#  'Other People’s Children',
#  'One True Loves',
#  'The Lost Weekend: A Love Story',
#  'A Thousand and One',
#  'Your Place or Mine',
#  'Love in the Time of Fentanyl',
#  'The Attachment Diaries',
#  'You Can Live Forever',
#  'A Tourist’s Guide to Love',
#  'Other People’s Children',
#  'One True Loves',
#  'The Lost Weekend: A Love Story',
#  'A Thousand and One',
#  'Your Place or Mine',
#  'Love in the Time of Fentanyl',
#  'The Attachment Diaries',
#  'You Can Live Forever',
#  'A Tourist’s Guide to Love',
#  'Other People’s Children',
#  'One True Loves',
#  'The Lost Weekend: A Love Story',
#  'A Thousand and One',
#  'Your Place or Mine',
#  'Love in the Time of Fentanyl',
#  'The Attachment Diaries',
#  'You Can Live Forever',
#  'A Tourist’s Guide to Love',
#  'Other People’s Children',
#  'One True Loves',
#  'The Lost Weekend: A Love Story',
#  'A Thousand and One',
#  'Your Place or Mine',
#  'Love in the Time of Fentanyl',
#  'The Attachment Diaries',
#  'You Can Live Forever',
#  'A Tourist’s Guide to Love',
#  'Other People’s Children',
#  'One True Loves',
#  'The Lost Weekend: A Love Story',
#  'A Thousand and One',
#  'Your Place or Mine',
#  'Love in the Time of Fentanyl',
#  'The Attachment Diaries',
#  'You Can Live Forever',
#  'A Tourist’s Guide to Love',
#  'Other People’s Children',
#  'One True Loves',
#  'The Lost Weekend: A Love Story',
#  'A Thousand and One',
#  'Your Place or Mine',
#  'Love in the Time of Fentanyl',
#  'The Attachment Diaries',
#  'You Can Live Forever',
#  'A Tourist’s Guide to Love',
#  'Other People’s Children',
#  'One True Loves',
#  'The Lost Weekend: A Love Story',
#  'A Thousand and One',
#  'Your Place or Mine',
#  'Love in the Time of Fentanyl']

# %% [markdown]
# ### Access The Movie Database API

# %%
# Prepare The Movie Database query
url = "https://api.themoviedb.org/3/search/movie?query="
tmdb_key_string = "&api_key=" + tmdb_api_key

# %%
# Create an empty list to store the results
tmdb_movies_list = []


# Create a request counter to sleep the requests after a multiple
# of 50 requests
request_counter = 1

# Loop through the titles
for title in list_of_titles:
    # Check if we need to sleep before making a request
    if request_counter % 50 == 0 and request_counter != 0:
        print(f"Sleeping for 1 seconds after {request_counter} requests")
        time.sleep(1)

    # Add 1 to the request counter
    request_counter += 1
    
    # Perform a "GET" request for The Movie Database
    query_url = url + title + tmdb_key_string    
    response = requests.get(query_url).json()
    print(f"Making request number: {request_counter} for: {title}")

    # Include a try clause to search for the full movie details.
    # Use the except clause to print out a statement if a movie
    # is not found.
    try:
        # Get movie id
        movie_id = response["results"][0]["id"]

        # Make a request for a the full movie details
        movide_id_url = f"https://api.themoviedb.org/3/movie/{movie_id}?api_key={tmdb_api_key}"

        # Execute "GET" request with url
        response = requests.get(movide_id_url).json()
    
        # Extract the genre names into a list
        genres = []
        for genre in response["genres"]:
            genres.append(genre["name"]) 

        # Extract the spoken_languages' English name into a list
        spoken_languages = []
        for language in response["spoken_languages"]:
            spoken_languages.append(language["english_name"])

        # Extract the production_countries' name into a list
        production_countries = []
        for country in response["production_countries"]:
            production_countries.append(country["name"])

        # Add the relevant data to a dictionary and
        # append it to the tmdb_movies_list list
        tmdb_movies_dict = {
            "title": response["title"],
            "original_title": response["original_title"],
            "original_language": response["original_language"],
            "homepage": response["homepage"],
            "overview": response["overview"],
            "popularity": response["popularity"],                       
            "budget": response["budget"],
            "runtime": response["runtime"],
            "revenue": response["revenue"],
            "release_date": response["release_date"],
            "vote_average": response["vote_average"],
            "vote_count": response["vote_count"],
            "genres": genres,
            "spoken_languages": spoken_languages,
            "production_countries": production_countries
        }
        tmdb_movies_list.append(tmdb_movies_dict)
        # Print out the title that was found
    except:
        print(f"Movie not found: {title}")
# Out:
# Making request number: 2 for: The Attachment Diaries
# Making request number: 3 for: You Can Live Forever
# Making request number: 4 for: A Tourist’s Guide to Love
# Making request number: 5 for: Other People’s Children
# Making request number: 6 for: One True Loves
# Making request number: 7 for: The Lost Weekend: A Love Story
# Making request number: 8 for: A Thousand and One
# Making request number: 9 for: Your Place or Mine
# Making request number: 10 for: Love in the Time of Fentanyl
# Making request number: 11 for: The Attachment Diaries
# Making request number: 12 for: You Can Live Forever
# Making request number: 13 for: A Tourist’s Guide to Love
# Making request number: 14 for: Other People’s Children
# Making request number: 15 for: One True Loves
# Making request number: 16 for: The Lost Weekend: A Love Story
# Making request number: 17 for: A Thousand and One
# Making request number: 18 for: Your Place or Mine
# Making request number: 19 for: Love in the Time of Fentanyl
# Making request number: 20 for: The Attachment Diaries
# Making request number: 21 for: You Can Live Forever
# Making request number: 22 for: A Tourist’s Guide to Love
# Making request number: 23 for: Other People’s Children
# Making request number: 24 for: One True Loves
# Making request number: 25 for: The Lost Weekend: A Love Story
# Making request number: 26 for: A Thousand and One
# Making request number: 27 for: Your Place or Mine
# Making request number: 28 for: Love in the Time of Fentanyl
# Making request number: 29 for: The Attachment Diaries
# Making request number: 30 for: You Can Live Forever
# Making request number: 31 for: A Tourist’s Guide to Love
# Making request number: 32 for: Other People’s Children
# Making request number: 33 for: One True Loves
# Making request number: 34 for: The Lost Weekend: A Love Story
# Making request number: 35 for: A Thousand and One
# Making request number: 36 for: Your Place or Mine
# Making request number: 37 for: Love in the Time of Fentanyl
# Making request number: 38 for: The Attachment Diaries
# Making request number: 39 for: You Can Live Forever
# Making request number: 40 for: A Tourist’s Guide to Love
# Making request number: 41 for: Other People’s Children
# Making request number: 42 for: One True Loves
# Making request number: 43 for: The Lost Weekend: A Love Story
# Making request number: 44 for: A Thousand and One
# Making request number: 45 for: Your Place or Mine
# Making request number: 46 for: Love in the Time of Fentanyl
# Making request number: 47 for: The Attachment Diaries
# Making request number: 48 for: You Can Live Forever
# Making request number: 49 for: A Tourist’s Guide to Love
# Making request number: 50 for: Other People’s Children
# Sleeping for 1 seconds after 50 requests
# Making request number: 51 for: One True Loves
# Making request number: 52 for: The Lost Weekend: A Love Story
# Making request number: 53 for: A Thousand and One
# Making request number: 54 for: Your Place or Mine
# Making request number: 55 for: Love in the Time of Fentanyl
# Making request number: 56 for: The Attachment Diaries
# Making request number: 57 for: You Can Live Forever
# Making request number: 58 for: A Tourist’s Guide to Love
# Making request number: 59 for: Other People’s Children
# Making request number: 60 for: One True Loves
# Making request number: 61 for: The Lost Weekend: A Love Story
# Making request number: 62 for: A Thousand and One
# Making request number: 63 for: Your Place or Mine
# Making request number: 64 for: Love in the Time of Fentanyl
# Making request number: 65 for: The Attachment Diaries
# Making request number: 66 for: You Can Live Forever
# Making request number: 67 for: A Tourist’s Guide to Love
# Making request number: 68 for: Other People’s Children
# Making request number: 69 for: One True Loves
# Making request number: 70 for: The Lost Weekend: A Love Story
# Making request number: 71 for: A Thousand and One
# Making request number: 72 for: Your Place or Mine
# Making request number: 73 for: Love in the Time of Fentanyl
# Making request number: 74 for: The Attachment Diaries
# Making request number: 75 for: You Can Live Forever
# Making request number: 76 for: A Tourist’s Guide to Love
# Making request number: 77 for: Other People’s Children
# Making request number: 78 for: One True Loves
# Making request number: 79 for: The Lost Weekend: A Love Story
# Making request number: 80 for: A Thousand and One
# Making request number: 81 for: Your Place or Mine
# Making request number: 82 for: Love in the Time of Fentanyl
# Making request number: 83 for: The Attachment Diaries
# Making request number: 84 for: You Can Live Forever
# Making request number: 85 for: A Tourist’s Guide to Love
# Making request number: 86 for: Other People’s Children
# Making request number: 87 for: One True Loves
# Making request number: 88 for: The Lost Weekend: A Love Story
# Making request number: 89 for: A Thousand and One
# Making request number: 90 for: Your Place or Mine
# Making request number: 91 for: Love in the Time of Fentanyl
# Making request number: 92 for: The Attachment Diaries
# Making request number: 93 for: You Can Live Forever
# Making request number: 94 for: A Tourist’s Guide to Love
# Making request number: 95 for: Other People’s Children
# Making request number: 96 for: One True Loves
# Making request number: 97 for: The Lost Weekend: A Love Story
# Making request number: 98 for: A Thousand and One
# Making request number: 99 for: Your Place or Mine
# Making request number: 100 for: Love in the Time of Fentanyl
# Sleeping for 1 seconds after 100 requests
# Making request number: 101 for: The Attachment Diaries
# Making request number: 102 for: You Can Live Forever
# Making request number: 103 for: A Tourist’s Guide to Love
# Making request number: 104 for: Other People’s Children
# Making request number: 105 for: One True Loves
# Making request number: 106 for: The Lost Weekend: A Love Story
# Making request number: 107 for: A Thousand and One
# Making request number: 108 for: Your Place or Mine
# Making request number: 109 for: Love in the Time of Fentanyl
# Making request number: 110 for: The Attachment Diaries
# Making request number: 111 for: You Can Live Forever
# Making request number: 112 for: A Tourist’s Guide to Love
# Making request number: 113 for: Other People’s Children
# Making request number: 114 for: One True Loves
# Making request number: 115 for: The Lost Weekend: A Love Story
# Making request number: 116 for: A Thousand and One
# Making request number: 117 for: Your Place or Mine
# Making request number: 118 for: Love in the Time of Fentanyl
# Making request number: 119 for: The Attachment Diaries
# Making request number: 120 for: You Can Live Forever
# Making request number: 121 for: A Tourist’s Guide to Love
# Making request number: 122 for: Other People’s Children
# Making request number: 123 for: One True Loves
# Making request number: 124 for: The Lost Weekend: A Love Story
# Making request number: 125 for: A Thousand and One
# Making request number: 126 for: Your Place or Mine
# Making request number: 127 for: Love in the Time of Fentanyl
# Making request number: 128 for: The Attachment Diaries
# Making request number: 129 for: You Can Live Forever
# Making request number: 130 for: A Tourist’s Guide to Love
# Making request number: 131 for: Other People’s Children
# Making request number: 132 for: One True Loves
# Making request number: 133 for: The Lost Weekend: A Love Story
# Making request number: 134 for: A Thousand and One
# Making request number: 135 for: Your Place or Mine
# Making request number: 136 for: Love in the Time of Fentanyl
# Making request number: 137 for: The Attachment Diaries
# Making request number: 138 for: You Can Live Forever
# Making request number: 139 for: A Tourist’s Guide to Love
# Making request number: 140 for: Other People’s Children
# Making request number: 141 for: One True Loves
# Making request number: 142 for: The Lost Weekend: A Love Story
# Making request number: 143 for: A Thousand and One
# Making request number: 144 for: Your Place or Mine
# Making request number: 145 for: Love in the Time of Fentanyl
# Making request number: 146 for: The Attachment Diaries
# Making request number: 147 for: You Can Live Forever
# Making request number: 148 for: A Tourist’s Guide to Love
# Making request number: 149 for: Other People’s Children
# Making request number: 150 for: One True Loves
# Sleeping for 1 seconds after 150 requests
# Making request number: 151 for: The Lost Weekend: A Love Story
# Making request number: 152 for: A Thousand and One
# Making request number: 153 for: Your Place or Mine
# Making request number: 154 for: Love in the Time of Fentanyl
# Making request number: 155 for: The Attachment Diaries
# Making request number: 156 for: You Can Live Forever
# Making request number: 157 for: A Tourist’s Guide to Love
# Making request number: 158 for: Other People’s Children
# Making request number: 159 for: One True Loves
# Making request number: 160 for: The Lost Weekend: A Love Story
# Making request number: 161 for: A Thousand and One
# Making request number: 162 for: Your Place or Mine
# Making request number: 163 for: Love in the Time of Fentanyl
# Making request number: 164 for: The Attachment Diaries
# Making request number: 165 for: You Can Live Forever
# Making request number: 166 for: A Tourist’s Guide to Love
# Making request number: 167 for: Other People’s Children
# Making request number: 168 for: One True Loves
# Making request number: 169 for: The Lost Weekend: A Love Story
# Making request number: 170 for: A Thousand and One
# Making request number: 171 for: Your Place or Mine
# Making request number: 172 for: Love in the Time of Fentanyl
# Making request number: 173 for: The Attachment Diaries
# Making request number: 174 for: You Can Live Forever
# Making request number: 175 for: A Tourist’s Guide to Love
# Making request number: 176 for: Other People’s Children
# Making request number: 177 for: One True Loves
# Making request number: 178 for: The Lost Weekend: A Love Story
# Making request number: 179 for: A Thousand and One
# Making request number: 180 for: Your Place or Mine
# Making request number: 181 for: Love in the Time of Fentanyl

# %%
# Preview the first 5 results in JSON format
# Use json.dumps with argument indent=4 to format data
print(json.dumps(tmdb_movies_list[:5], indent=4))
# Out:
# [
#     {
#         "title": "The Attachment Diaries",
#         "original_title": "El apego",
#         "original_language": "es",
#         "homepage": "",
#         "overview": "Argentina, 1970s. A desperate young woman goes to a clinic to have a clandestine abortion. As her pregnancy is already through the fourth month, the doctor refuses. Instead, she proposes to sell the baby to one of her clients and offers to provide shelter in her house until the child is born. Their disturbed personalities will become intertwined in a strange and dangerous relationship.",
#         "popularity": 0.776,
#         "budget": 0,
#         "runtime": 102,
#         "revenue": 0,
#         "release_date": "2021-10-07",
#         "vote_average": 4.0,
#         "vote_count": 2,
#         "genres": [
#             "Drama",
#             "Mystery",
#             "Thriller",
#             "Horror"
#         ],
#         "spoken_languages": [
#             "Spanish"
#         ],
#         "production_countries": [
#             "Argentina"
#         ]
#     },
#     {
#         "title": "You Can Live Forever",
#         "original_title": "You Can Live Forever",
#         "original_language": "en",
#         "homepage": "https://gooddeedentertainment.com/you-can-live-forever/",
#         "overview": "When Jaime, a gay teenager, is sent to live in a community of Jehovah's Witnesses in small-town Quebec, she falls madly in love with a devout Witness girl. The two embark on an intense affair with consequences that will reshape the rest of their lives.",
#         "popularity": 6.716,
#         "budget": 0,
#         "runtime": 96,
#         "revenue": 15055,
#         "release_date": "2023-03-24",
#         "vote_average": 7.077,
#         "vote_count": 26,
#         "genres": [
#             "Drama",
#             "Romance"
#         ],
#         "spoken_languages": [
#             "English",
#             "French"
#         ],
#         "production_countries": [
#             "Canada",
#             "United States of America"
#         ]
#     },
#     {
#         "title": "A Tourist's Guide to Love",
#         "original_title": "A Tourist's Guide to Love",
#         "original_language": "en",
#         "homepage": "https://www.netflix.com/title/81424906",
#         "overview": "After an unexpected break up, a travel executive accepts an assignment to go undercover and learn about the tourist industry in Vietnam. Along the way, she finds adventure and romance with her Vietnamese expat tour guide and they decide to hijack the tour bus in order to explore life and love off the beaten path.",
#         "popularity": 11.709,
#         "budget": 0,
#         "runtime": 96,
#         "revenue": 0,
#         "release_date": "2023-04-21",
#         "vote_average": 6.365,
#         "vote_count": 144,
#         "genres": [
#             "Romance",
#             "Comedy"
#         ],
#         "spoken_languages": [
#             "English",
#             "Vietnamese"
#         ],
#         "production_countries": [
#             "United States of America"
#         ]
#     },
#     {
#         "title": "Other People's Children",
#         "original_title": "Les Enfants des autres",
#         "original_language": "fr",
#         "homepage": "https://www.wildbunch.biz/movie/other-peoples-children/",
#         "overview": "Rachel loves her life, her students, her friends, her ex, her guitar lessons. When she falls in love with Ali, she grows close to his 4-year-old daughter, Leila. She tucks her in, looks after her, and loves her like a mother... which she isn\u2019t. Not yet. Rachel is 40. The desire for a family of her own is growing stronger, and the clock is ticking. Is it too late?",
#         "popularity": 10.394,
#         "budget": 0,
#         "runtime": 104,
#         "revenue": 84178,
#         "release_date": "2022-09-21",
#         "vote_average": 6.913,
#         "vote_count": 161,
#         "genres": [
#             "Drama",
#             "Comedy"
#         ],
#         "spoken_languages": [
#             "English",
#             "French"
#         ],
#         "production_countries": [
#             "France"
#         ]
#     },
#     {
#         "title": "One True Loves",
#         "original_title": "One True Loves",
#         "original_language": "en",
#         "homepage": "",
#         "overview": "Emma and Jesse are living the perfect life together, until Jesse disappears in a tragic helicopter crash on their first wedding anniversary. Four years later, Emma has found happiness again and is about to marry her best friend when Jesse resurfaces, turning her world upside down and leaving her torn between two great loves.",
#         "popularity": 15.431,
#         "budget": 0,
#         "runtime": 100,
#         "revenue": 37820,
#         "release_date": "2023-04-07",
#         "vote_average": 6.66,
#         "vote_count": 53,
#         "genres": [
#             "Romance",
#             "Drama",
#             "Comedy"
#         ],
#         "spoken_languages": [
#             "English"
#         ],
#         "production_countries": [
#             "Germany",
#             "United States of America"
#         ]
#     }
# ]

# %%
# Convert the results to a DataFrame
tmdb_df = pd.DataFrame(tmdb_movies_list)
tmdb_df.head()
# Out:
#                        title             original_title original_language  \
# 0     The Attachment Diaries                   El apego                es
# 1       You Can Live Forever       You Can Live Forever                en
# 2  A Tourist's Guide to Love  A Tourist's Guide to Love                en
# 3    Other People's Children     Les Enfants des autres                fr
# 4             One True Loves             One True Loves                en
#
#                                             homepage  \
# 0
# 1  https://gooddeedentertainment.com/you-can-live...
# 2             https://www.netflix.com/title/81424906
# 3  https://www.wildbunch.biz/movie/other-peoples-...
# 4
#
#                                             overview  popularity  budget  \
# 0  Argentina, 1970s. A desperate young woman goes...       0.776       0
# 1  When Jaime, a gay teenager, is sent to live in...       6.716       0
# 2  After an unexpected break up, a travel executi...      11.709       0
# 3  Rachel loves her life, her students, her frien...      10.394       0
# 4  Emma and Jesse are living the perfect life tog...      15.431       0
#
#    runtime  revenue release_date  vote_average  vote_count  \
# 0      102        0   2021-10-07         4.000           2
# 1       96    15055   2023-03-24         7.077          26
# 2       96        0   2023-04-21         6.365         144
# 3      104    84178   2022-09-21         6.913         161
# 4      100    37820   2023-04-07         6.660          53
#
#                                genres       spoken_languages  \
# 0  [Drama, Mystery, Thriller, Horror]              [Spanish]
# 1                    [Drama, Romance]      [English, French]
# 2                   [Romance, Comedy]  [English, Vietnamese]
# 3                     [Drama, Comedy]      [English, French]
# 4            [Romance, Drama, Comedy]              [English]
#
#                   production_countries
# 0                          [Argentina]
# 1   [Canada, United States of America]
# 2           [United States of America]
# 3                             [France]
# 4  [Germany, United States of America]

# %% [markdown]
# ### Merge and Clean the Data for Export

# %%
# Merge the New York Times reviews and TMDB DataFrames on title
merged_df = pd.merge(reviews_df, tmdb_df, on="title")
merged_df.head()
# Out:
#                                              web_url  \
# 0  https://www.nytimes.com/2023/05/25/movies/the-...
# 1  https://www.nytimes.com/2023/05/25/movies/the-...
# 2  https://www.nytimes.com/2023/05/25/movies/the-...
# 3  https://www.nytimes.com/2023/05/25/movies/the-...
# 4  https://www.nytimes.com/2023/05/25/movies/the-...
#
#                                              snippet              source  \
# 0  A gynecologist and her patient form a horrifyi...  The New York Times
# 1  A gynecologist and her patient form a horrifyi...  The New York Times
# 2  A gynecologist and her patient form a horrifyi...  The New York Times
# 3  A gynecologist and her patient form a horrifyi...  The New York Times
# 4  A gynecologist and her patient form a horrifyi...  The New York Times
#
#                                             keywords  \
# 0  subject: Movies;creative_works: The Attachment...
# 1  subject: Movies;creative_works: The Attachment...
# 2  subject: Movies;creative_works: The Attachment...
# 3  subject: Movies;creative_works: The Attachment...
# 4  subject: Movies;creative_works: The Attachment...
#
#                    pub_date  word_count  \
# 0  2023-05-25T11:00:03+0000         295
# 1  2023-05-25T11:00:03+0000         295
# 2  2023-05-25T11:00:03+0000         295
# 3  2023-05-25T11:00:03+0000         295
# 4  2023-05-25T11:00:03+0000         295
#
#                                  headline.main headline.kicker  \
# 0  ‘The Attachment Diaries’ Review: Love, Sick            None
# 1  ‘The Attachment Diaries’ Review: Love, Sick            None
# 2  ‘The Attachment Diaries’ Review: Love, Sick            None
# 3  ‘The Attachment Diaries’ Review: Love, Sick            None
# 4  ‘The Attachment Diaries’ Review: Love, Sick            None
#
#   headline.content_kicker headline.print_headline  ... popularity budget  \
# 0                    None  The Attachment Diaries  ...      0.776      0
# 1                    None  The Attachment Diaries  ...      0.776      0
# 2                    None  The Attachment Diaries  ...      0.776      0
# 3                    None  The Attachment Diaries  ...      0.776      0
# 4                    None  The Attachment Diaries  ...      0.776      0
#
#   runtime revenue release_date vote_average vote_count  \
# 0     102       0   2021-10-07          4.0          2
# 1     102       0   2021-10-07          4.0          2
# 2     102       0   2021-10-07          4.0          2
# 3     102       0   2021-10-07          4.0          2
# 4     102       0   2021-10-07          4.0          2
#
#                                genres spoken_languages production_countries
# 0  [Drama, Mystery, Thriller, Horror]        [Spanish]          [Argentina]
# 1  [Drama, Mystery, Thriller, Horror]        [Spanish]          [Argentina]
# 2  [Drama, Mystery, Thriller, Horror]        [Spanish]          [Argentina]
# 3  [Drama, Mystery, Thriller, Horror]        [Spanish]          [Argentina]
# 4  [Drama, Mystery, Thriller, Horror]        [Spanish]          [Argentina]
#
# [5 rows x 31 columns]

# %%
# Remove list brackets and quotation marks on the columns containing lists
# Create a list of the columns that need fixing
columns_to_fix = ["genres", "spoken_languages", "production_countries"]

# Create a list of characters to remove
characters_to_remove = ["[", "]", "'"]

# Loop through the list of columns to fix
for column in columns_to_fix:
    # Convert the column to type 'str'
    merged_df[column] = merged_df[column].astype(str)
    # Loop through characters to remove
    for character in characters_to_remove:
        merged_df[column] = merged_df[column].str.replace(character, "")

# Display the fixed DataFrame
merged_df.head()
# Out:
#                                              web_url  \
# 0  https://www.nytimes.com/2023/05/25/movies/the-...
# 1  https://www.nytimes.com/2023/05/25/movies/the-...
# 2  https://www.nytimes.com/2023/05/25/movies/the-...
# 3  https://www.nytimes.com/2023/05/25/movies/the-...
# 4  https://www.nytimes.com/2023/05/25/movies/the-...
#
#                                              snippet              source  \
# 0  A gynecologist and her patient form a horrifyi...  The New York Times
# 1  A gynecologist and her patient form a horrifyi...  The New York Times
# 2  A gynecologist and her patient form a horrifyi...  The New York Times
# 3  A gynecologist and her patient form a horrifyi...  The New York Times
# 4  A gynecologist and her patient form a horrifyi...  The New York Times
#
#                                             keywords  \
# 0  subject: Movies;creative_works: The Attachment...
# 1  subject: Movies;creative_works: The Attachment...
# 2  subject: Movies;creative_works: The Attachment...
# 3  subject: Movies;creative_works: The Attachment...
# 4  subject: Movies;creative_works: The Attachment...
#
#                    pub_date  word_count  \
# 0  2023-05-25T11:00:03+0000         295
# 1  2023-05-25T11:00:03+0000         295
# 2  2023-05-25T11:00:03+0000         295
# 3  2023-05-25T11:00:03+0000         295
# 4  2023-05-25T11:00:03+0000         295
#
#                                  headline.main headline.kicker  \
# 0  ‘The Attachment Diaries’ Review: Love, Sick            None
# 1  ‘The Attachment Diaries’ Review: Love, Sick            None
# 2  ‘The Attachment Diaries’ Review: Love, Sick            None
# 3  ‘The Attachment Diaries’ Review: Love, Sick            None
# 4  ‘The Attachment Diaries’ Review: Love, Sick            None
#
#   headline.content_kicker headline.print_headline  ... popularity budget  \
# 0                    None  The Attachment Diaries  ...      0.776      0
# 1                    None  The Attachment Diaries  ...      0.776      0
# 2                    None  The Attachment Diaries  ...      0.776      0
# 3                    None  The Attachment Diaries  ...      0.776      0
# 4                    None  The Attachment Diaries  ...      0.776      0
#
#   runtime revenue release_date vote_average vote_count  \
# 0     102       0   2021-10-07          4.0          2
# 1     102       0   2021-10-07          4.0          2
# 2     102       0   2021-10-07          4.0          2
# 3     102       0   2021-10-07          4.0          2
# 4     102       0   2021-10-07          4.0          2
#
#                              genres spoken_languages production_countries
# 0  Drama, Mystery, Thriller, Horror          Spanish            Argentina
# 1  Drama, Mystery, Thriller, Horror          Spanish            Argentina
# 2  Drama, Mystery, Thriller, Horror          Spanish            Argentina
# 3  Drama, Mystery, Thriller, Horror          Spanish            Argentina
# 4  Drama, Mystery, Thriller, Horror          Spanish            Argentina
#
# [5 rows x 31 columns]

# %%
# Drop "byline.person" column
merged_df = merged_df.drop(columns=["byline.person"], axis=0)
merged_df.head()
# Out:
#                                              web_url  \
# 0  https://www.nytimes.com/2023/05/25/movies/the-...
# 1  https://www.nytimes.com/2023/05/25/movies/the-...
# 2  https://www.nytimes.com/2023/05/25/movies/the-...
# 3  https://www.nytimes.com/2023/05/25/movies/the-...
# 4  https://www.nytimes.com/2023/05/25/movies/the-...
#
#                                              snippet              source  \
# 0  A gynecologist and her patient form a horrifyi...  The New York Times
# 1  A gynecologist and her patient form a horrifyi...  The New York Times
# 2  A gynecologist and her patient form a horrifyi...  The New York Times
# 3  A gynecologist and her patient form a horrifyi...  The New York Times
# 4  A gynecologist and her patient form a horrifyi...  The New York Times
#
#                                             keywords  \
# 0  subject: Movies;creative_works: The Attachment...
# 1  subject: Movies;creative_works: The Attachment...
# 2  subject: Movies;creative_works: The Attachment...
# 3  subject: Movies;creative_works: The Attachment...
# 4  subject: Movies;creative_works: The Attachment...
#
#                    pub_date  word_count  \
# 0  2023-05-25T11:00:03+0000         295
# 1  2023-05-25T11:00:03+0000         295
# 2  2023-05-25T11:00:03+0000         295
# 3  2023-05-25T11:00:03+0000         295
# 4  2023-05-25T11:00:03+0000         295
#
#                                  headline.main headline.kicker  \
# 0  ‘The Attachment Diaries’ Review: Love, Sick            None
# 1  ‘The Attachment Diaries’ Review: Love, Sick            None
# 2  ‘The Attachment Diaries’ Review: Love, Sick            None
# 3  ‘The Attachment Diaries’ Review: Love, Sick            None
# 4  ‘The Attachment Diaries’ Review: Love, Sick            None
#
#   headline.content_kicker headline.print_headline  ... popularity budget  \
# 0                    None  The Attachment Diaries  ...      0.776      0
# 1                    None  The Attachment Diaries  ...      0.776      0
# 2                    None  The Attachment Diaries  ...      0.776      0
# 3                    None  The Attachment Diaries  ...      0.776      0
# 4                    None  The Attachment Diaries  ...      0.776      0
#
#   runtime revenue release_date vote_average vote_count  \
# 0     102       0   2021-10-07          4.0          2
# 1     102       0   2021-10-07          4.0          2
# 2     102       0   2021-10-07          4.0          2
# 3     102       0   2021-10-07          4.0          2
# 4     102       0   2021-10-07          4.0          2
#
#                              genres spoken_languages production_countries
# 0  Drama, Mystery, Thriller, Horror          Spanish            Argentina
# 1  Drama, Mystery, Thriller, Horror          Spanish            Argentina
# 2  Drama, Mystery, Thriller, Horror          Spanish            Argentina
# 3  Drama, Mystery, Thriller, Horror          Spanish            Argentina
# 4  Drama, Mystery, Thriller, Horror          Spanish            Argentina
#
# [5 rows x 30 columns]

# %%
# Delete duplicate rows and reset index
merged_df = merged_df.drop_duplicates(subset="title", keep=False).reset_index(drop=True)
merged_df
# Out:
# Empty DataFrame
# Columns: [web_url, snippet, source, keywords, pub_date, word_count, headline.main, headline.kicker, headline.content_kicker, headline.print_headline, headline.name, headline.seo, headline.sub, byline.original, byline.organization, title, original_title, original_language, homepage, overview, popularity, budget, runtime, revenue, release_date, vote_average, vote_count, genres, spoken_languages, production_countries]
# Index: []
#
# [0 rows x 30 columns]

# %%
# Export data to CSV without the index
merged_df.to_csv("output/merged_cleaned_data.csv", index=False, header=True)
